# %% [markdown]
# <a href="https://colab.research.google.com/github/Linaqruf/modelscope-migration/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Linaqruf/modelscope-migration
# %cd modelscope-migration
# !pip install -q -r requirements.txt
# !python app.py --share
# Out:
# Cloning into 'modelscope-migration'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 39 (delta 18), reused 15 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 29.27 KiB | 7.32 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/modelscope-migration
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 69.8 MB/s eta 0:00:00
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://5b59306500c1f6056e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
